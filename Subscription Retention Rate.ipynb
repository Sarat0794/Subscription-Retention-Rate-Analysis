# %%
#Importing essential libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importing the dataset
dataset=pd.read_csv('Subscription.csv')

# %%
# Getting insights of the data

# %%
dataset.head()
# Out:
#    user_id subscription_signup_date  subscription_monthly_cost  country  \
# 0     1459            January, 2015                         29    Spain
# 1    12474            January, 2015                         49   France
# 2    12294            January, 2015                         49  Germany
# 3     3878            January, 2015                         49    China
# 4     9567            January, 2015                         49       UK
#
#   source  billing_cycles  is_active
# 0    ads               4          0
# 1    ads               5          0
# 2    ads               2          0
# 3    ads               1          0
# 4    ads               5          0

# %%
dataset['subscription_monthly_cost'].value_counts()
# Out:
# 49    300397
# 29    146362
# 99     53241
# Name: subscription_monthly_cost, dtype: int64

# %%
dataset.corr()
# Out:
#                             user_id  subscription_monthly_cost  \
# user_id                    1.000000                  -0.001013
# subscription_monthly_cost -0.001013                   1.000000
# billing_cycles            -0.000022                  -0.277860
# is_active                 -0.001682                  -0.212589
#
#                            billing_cycles  is_active
# user_id                         -0.000022  -0.001682
# subscription_monthly_cost       -0.277860  -0.212589
# billing_cycles                   1.000000   0.830021
# is_active                        0.830021   1.000000

# %%
dataset.describe()
# Out:
#              user_id  subscription_monthly_cost  billing_cycles      is_active
# count  500000.000000              500000.000000   500000.000000  500000.000000
# mean   250000.500000                  48.469620        2.384970       0.099998
# std    144337.711634                  19.570745        2.254952       0.299998
# min         1.000000                  29.000000        1.000000       0.000000
# 25%    125000.750000                  29.000000        1.000000       0.000000
# 50%    250000.500000                  49.000000        1.000000       0.000000
# 75%    375000.250000                  49.000000        3.000000       0.000000
# max    500000.000000                  99.000000        8.000000       1.000000

# %%
dataset
# Out:
#         user_id subscription_signup_date  subscription_monthly_cost  country  \
# 0          1459            January, 2015                         29    Spain
# 1         12474            January, 2015                         49   France
# 2         12294            January, 2015                         49  Germany
# 3          3878            January, 2015                         49    China
# 4          9567            January, 2015                         49       UK
# 5           790            January, 2015                         49       US
# 6         12214            January, 2015                         49   France
# 7          7341            January, 2015                         29       US
# 8          1026            January, 2015                         99    Spain
# 9         11647            January, 2015                         49       US
# 10         7632            January, 2015                         49   France
# ...

# %%
#Placing the data with pricepoints=29 into a separate dataset29
dataset29= dataset[dataset.subscription_monthly_cost==29]
dataset29
# Out:
#         user_id subscription_signup_date  subscription_monthly_cost  country  \
# 0          1459            January, 2015                         29    Spain
# 7          7341            January, 2015                         29       US
# 14         5209            January, 2015                         29       UK
# 18         3054            January, 2015                         29    China
# 22        11799            January, 2015                         29    Spain
# 25         7639            January, 2015                         29  Germany
# 28         8865            January, 2015                         29       US
# 30         5237            January, 2015                         29    Spain
# 33        11002            January, 2015                         29  Germany
# 34         1411            January, 2015                         29       US
# 37         1829            January, 2015                         29       US
# ...

# %%
dataset49=dataset[dataset.subscription_monthly_cost==49]
dataset49
# Out:
#         user_id subscription_signup_date  subscription_monthly_cost  country  \
# 1         12474            January, 2015                         49   France
# 2         12294            January, 2015                         49  Germany
# 3          3878            January, 2015                         49    China
# 4          9567            January, 2015                         49       UK
# 5           790            January, 2015                         49       US
# 6         12214            January, 2015                         49   France
# 9         11647            January, 2015                         49       US
# 10         7632            January, 2015                         49   France
# 11         9995            January, 2015                         49       UK
# 13         4017            January, 2015                         49    Spain
# 15         8403            January, 2015                         49       UK
# ...

# %%
dataset99=dataset[dataset.subscription_monthly_cost==99]
dataset99
# Out:
#         user_id subscription_signup_date  subscription_monthly_cost  country  \
# 8          1026            January, 2015                         99    Spain
# 12         7715            January, 2015                         99    China
# 48         4718            January, 2015                         99       UK
# 55         6085            January, 2015                         99   France
# 72         3192            January, 2015                         99  Germany
# 73         8880            January, 2015                         99       US
# 83         2428            January, 2015                         99   France
# 90        12596            January, 2015                         99       UK
# 91         7938            January, 2015                         99  Germany
# 95        12078            January, 2015                         99       UK
# 108        8949            January, 2015                         99       UK
# ...

# %%
#Checking the number of users who are stil active
dataset29['billing_cycles'].value_counts()
# Out:
# 1    57441
# 8    34527
# 2    21818
# 3    12037
# 4     7787
# 5     5505
# 6     4136
# 7     3111
# Name: billing_cycles, dtype: int64

# %%
dataset49['billing_cycles'].value_counts()
# Out:
# 1    185145
# 2     53296
# 3     21690
# 8     14673
# 4     11288
# 5      6727
# 6      4405
# 7      3173
# Name: billing_cycles, dtype: int64

# %%
dataset99['billing_cycles'].value_counts()
# Out:
# 1    44788
# 2     4724
# 3     1471
# 8      799
# 4      678
# 5      399
# 6      226
# 7      156
# Name: billing_cycles, dtype: int64

# %%
datasetADS=dataset[dataset.source=='ads']
datasetADS
# Out:
#         user_id subscription_signup_date  subscription_monthly_cost  country  \
# 0          1459            January, 2015                         29    Spain
# 1         12474            January, 2015                         49   France
# 2         12294            January, 2015                         49  Germany
# 3          3878            January, 2015                         49    China
# 4          9567            January, 2015                         49       UK
# 5           790            January, 2015                         49       US
# 6         12214            January, 2015                         49   France
# 7          7341            January, 2015                         29       US
# 8          1026            January, 2015                         99    Spain
# 9         11647            January, 2015                         49       US
# 11         9995            January, 2015                         49       UK
# ...

# %%
datasetADS['billing_cycles'].value_counts()
# Out:
# 1    253293
# 2     69125
# 3     28800
# 8     27453
# 4     15604
# 5      9498
# 6      6336
# 7      4360
# Name: billing_cycles, dtype: int64

# %%
datasetSEO=dataset[dataset.source=='seo']
datasetSEO
# Out:
#         user_id subscription_signup_date  subscription_monthly_cost  country  \
# 10         7632            January, 2015                         49   France
# 12         7715            January, 2015                         99    China
# 16        10402            January, 2015                         49    Spain
# 17         7641            January, 2015                         49    Spain
# 24         3013            January, 2015                         49       UK
# 29         3883            January, 2015                         49       US
# 36         9345            January, 2015                         49  Germany
# 38         3270            January, 2015                         49    Italy
# 40         5400            January, 2015                         29       US
# 47          295            January, 2015                         29    Spain
# 72         3192            January, 2015                         99  Germany
# ...

# %%
datasetSEO['billing_cycles'].value_counts()
# Out:
# 1    26739
# 8    11883
# 2     8700
# 3     5036
# 4     3137
# 5     2345
# 6     1784
# 7     1479
# Name: billing_cycles, dtype: int64

# %%
dataset8s=dataset[dataset.billing_cycles==8]
dataset8s
# Out:
#         user_id subscription_signup_date  subscription_monthly_cost  country  \
# 7          7341            January, 2015                         29       US
# 37         1829            January, 2015                         29       US
# 54          902            January, 2015                         29       US
# 62        12586            January, 2015                         29       US
# 70        11630            January, 2015                         49       UK
# 101        5216            January, 2015                         49       US
# 106       10588            January, 2015                         49    Italy
# 111        2130            January, 2015                         29    China
# 113        6752            January, 2015                         29   France
# 114        4589            January, 2015                         29    India
# 123        5333            January, 2015                         49       UK
# ...

# %%
dataset8s['source'].value_counts()
# Out:
# ads                27453
# seo                11883
# friend_referral    10663
# Name: source, dtype: int64

# %%
dataset29['source'].value_counts()
# Out:
# ads                121246
# seo                 18019
# friend_referral      7097
# Name: source, dtype: int64
